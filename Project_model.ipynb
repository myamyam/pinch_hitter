# %% [markdown]
# 모델 생성_최종

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import re
import schedule
import time
import tensorflow as tf

def model_update(file_path, name):
    
    seed = 0
    np.random.seed(seed)
    tf.random.set_seed(seed)
    
    # 데이터 로딩
    df = pd.read_csv(file_path)
    
    # 데이터 확인
    print(df.head())
    
    # 특성(X)과 타겟(y) 분리
    X = df.drop(columns=['Result'])
    y = df['Result']
    
    # 범주형 변수를 수치형 변수로 변환
    X = pd.get_dummies(X)
    
    # 데이터 분리
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=seed)
    
    # 데이터 표준화
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # 타겟 변수를 카테고리형으로 변환
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    
    # 딥러닝 모델 정의
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(2, activation='softmax'))  # 2개의 클래스로 분류
    
    # 모델 컴파일
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # 모델 학습
    model.fit(X_train, y_train, epochs=200, batch_size=32, validation_split=0.2)
    
    # 자동 중단 설정
    early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)
    
    # 모델 저장
    model_filename = './project_kbo/models/' + name+'_model.keras'
    checkpointer = ModelCheckpoint(filepath=model_filename, monitor = 'val_loss', verbose=1, save_best_only = True)
    
    # 모델 실행
    history = model.fit(X_test, y_test, validation_split=0.33, epochs=3500, batch_size=500, verbose = 0, callbacks=[early_stopping_callback, checkpointer])
    #model.save(model_filename)
    
    # 모델 평가
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"테스트 손실: {loss:.4f}")
    print(f"테스트 정확도: {accuracy:.4f}")
    print(f"모델 저장 완료: {model_filename}")

schedule.every().day.at("10:35").do(model_update)

# 테스트를 위해 즉시 실행
# List of files to preprocess
files_to_model = [
    ('./project_kbo/preprocess/강민호_preprocessed.csv', '강민호'),
    ('./project_kbo/preprocess/구자욱_preprocessed.csv', '구자욱'),
    ('./project_kbo/preprocess/김영웅_preprocessed.csv', '김영웅'),
    ('./project_kbo/preprocess/김재혁_preprocessed.csv', '김재혁'),
    ('./project_kbo/preprocess/김지찬_preprocessed.csv', '김지찬'),
    ('./project_kbo/preprocess/김헌곤_preprocessed.csv', '김헌곤'),
    ('./project_kbo/preprocess/김현준_preprocessed.csv', '김현준'),
    ('./project_kbo/preprocess/류지혁_preprocessed.csv', '류지혁'),
    ('./project_kbo/preprocess/박병호_preprocessed.csv', '박병호'),
    ('./project_kbo/preprocess/안주형_preprocessed.csv', '안주형'),
    ('./project_kbo/preprocess/윤정빈_preprocessed.csv', '윤정빈'),
    ('./project_kbo/preprocess/이병헌_preprocessed.csv', '이병헌'),
    ('./project_kbo/preprocess/이성규_preprocessed.csv', '이성규'),
    ('./project_kbo/preprocess/이재현_preprocessed.csv', '이재현'),
    ('./project_kbo/preprocess/전병우_preprocessed.csv', '전병우'),
]

# Preprocess each file
for file_path, name in files_to_model:
    model_update(file_path, name)

while True:
    schedule.run_pending()
    time.sleep(60)  # wait one minute
# Out:
#   Inning Pitcher Out Bases  Result
# 0     8회     손동현  무사  1,2루       0
# 1     7회      하트  2사    만루       0
# 2     9회     박영현  1사  1,2루       0
# 3     7회     한현희  2사  1,3루       0
# 4     6회      곽빈  2사    만루       0
# Epoch 1/200
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5597 - loss: 0.7141 - val_accuracy: 0.6818 - val_loss: 0.6327
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6164 - loss: 0.5971 - val_accuracy: 0.7273 - val_loss: 0.6066
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6502 - loss: 0.5444 - val_accuracy: 0.6818 - val_loss: 0.5986
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.1692e-04 - val_accuracy: 0.6818 - val_loss: 2.6651
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 4.1165e-04 - val_accuracy: 0.6818 - val_loss: 2.6694
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 4.0643e-04 - val_accuracy: 0.6818 - val_loss: 2.6735
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 4.0121e-04 - val_accuracy: 0.6818 - val_loss: 2.6777
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 3.9608e-04 - val_accuracy: 0.6818 - val_loss: 2.6819
#
# Epoch 1: val_loss improved from inf to 3.01879, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 2: val_loss improved from 3.01879 to 2.83422, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 3: val_loss improved from 2.83422 to 2.64110, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 4: val_loss improved from 2.64110 to 2.45424, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 5: val_loss improved from 2.45424 to 2.26847, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 6: val_loss improved from 2.26847 to 2.11433, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 7: val_loss improved from 2.11433 to 2.01097, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 8: val_loss improved from 2.01097 to 1.94941, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 9: val_loss improved from 1.94941 to 1.90887, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 10: val_loss improved from 1.90887 to 1.87990, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 11: val_loss improved from 1.87990 to 1.83669, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 12: val_loss improved from 1.83669 to 1.79809, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 13: val_loss improved from 1.79809 to 1.76635, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 14: val_loss improved from 1.76635 to 1.73387, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 15: val_loss improved from 1.73387 to 1.70522, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 16: val_loss improved from 1.70522 to 1.68273, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 17: val_loss improved from 1.68273 to 1.66601, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 18: val_loss improved from 1.66601 to 1.65437, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 19: val_loss improved from 1.65437 to 1.64818, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 20: val_loss improved from 1.64818 to 1.64479, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 21: val_loss improved from 1.64479 to 1.64449, saving model to ./project_kbo/models/강민호_model.keras
#
# Epoch 22: val_loss did not improve from 1.64449
#
# Epoch 23: val_loss did not improve from 1.64449
#
# Epoch 24: val_loss did not improve from 1.64449
#
# Epoch 25: val_loss did not improve from 1.64449
#
# Epoch 26: val_loss did not improve from 1.64449
#
# Epoch 27: val_loss did not improve from 1.64449
#
# Epoch 28: val_loss did not improve from 1.64449
#
# Epoch 29: val_loss did not improve from 1.64449
#
# Epoch 30: val_loss did not improve from 1.64449
#
# Epoch 31: val_loss did not improve from 1.64449
#
# Epoch 32: val_loss did not improve from 1.64449
#
# Epoch 33: val_loss did not improve from 1.64449
#
# Epoch 34: val_loss did not improve from 1.64449
#
# Epoch 35: val_loss did not improve from 1.64449
#
# Epoch 36: val_loss did not improve from 1.64449
#
# Epoch 37: val_loss did not improve from 1.64449
#
# Epoch 38: val_loss did not improve from 1.64449
#
# Epoch 39: val_loss did not improve from 1.64449
#
# Epoch 40: val_loss did not improve from 1.64449
#
# Epoch 41: val_loss did not improve from 1.64449
#
# Epoch 42: val_loss did not improve from 1.64449
#
# Epoch 43: val_loss did not improve from 1.64449
#
# Epoch 44: val_loss did not improve from 1.64449
#
# Epoch 45: val_loss did not improve from 1.64449
#
# Epoch 46: val_loss did not improve from 1.64449
#
# Epoch 47: val_loss did not improve from 1.64449
#
# Epoch 48: val_loss did not improve from 1.64449
#
# Epoch 49: val_loss did not improve from 1.64449
#
# Epoch 50: val_loss did not improve from 1.64449
#
# Epoch 51: val_loss did not improve from 1.64449
#
# Epoch 52: val_loss did not improve from 1.64449
#
# Epoch 53: val_loss did not improve from 1.64449
#
# Epoch 54: val_loss did not improve from 1.64449
#
# Epoch 55: val_loss did not improve from 1.64449
#
# Epoch 56: val_loss did not improve from 1.64449
#
# Epoch 57: val_loss did not improve from 1.64449
#
# Epoch 58: val_loss did not improve from 1.64449
#
# Epoch 59: val_loss did not improve from 1.64449
#
# Epoch 60: val_loss did not improve from 1.64449
#
# Epoch 61: val_loss did not improve from 1.64449
#
# Epoch 62: val_loss did not improve from 1.64449
#
# Epoch 63: val_loss did not improve from 1.64449
#
# Epoch 64: val_loss did not improve from 1.64449
#
# Epoch 65: val_loss did not improve from 1.64449
#
# Epoch 66: val_loss did not improve from 1.64449
#
# Epoch 67: val_loss did not improve from 1.64449
#
# Epoch 68: val_loss did not improve from 1.64449
#
# Epoch 69: val_loss did not improve from 1.64449
#
# Epoch 70: val_loss did not improve from 1.64449
#
# Epoch 71: val_loss did not improve from 1.64449
#
# Epoch 72: val_loss did not improve from 1.64449
#
# Epoch 73: val_loss did not improve from 1.64449
#
# Epoch 74: val_loss did not improve from 1.64449
#
# Epoch 75: val_loss did not improve from 1.64449
#
# Epoch 76: val_loss did not improve from 1.64449
#
# Epoch 77: val_loss did not improve from 1.64449
#
# Epoch 78: val_loss did not improve from 1.64449
#
# Epoch 79: val_loss did not improve from 1.64449
#
# Epoch 80: val_loss did not improve from 1.64449
#
# Epoch 81: val_loss did not improve from 1.64449
#
# Epoch 82: val_loss did not improve from 1.64449
#
# Epoch 83: val_loss did not improve from 1.64449
#
# Epoch 84: val_loss did not improve from 1.64449
#
# Epoch 85: val_loss did not improve from 1.64449
#
# Epoch 86: val_loss did not improve from 1.64449
#
# Epoch 87: val_loss did not improve from 1.64449
#
# Epoch 88: val_loss did not improve from 1.64449
#
# Epoch 89: val_loss did not improve from 1.64449
#
# Epoch 90: val_loss did not improve from 1.64449
#
# Epoch 91: val_loss did not improve from 1.64449
#
# Epoch 92: val_loss did not improve from 1.64449
#
# Epoch 93: val_loss did not improve from 1.64449
#
# Epoch 94: val_loss did not improve from 1.64449
#
# Epoch 95: val_loss did not improve from 1.64449
#
# Epoch 96: val_loss did not improve from 1.64449
#
# Epoch 97: val_loss did not improve from 1.64449
#
# Epoch 98: val_loss did not improve from 1.64449
#
# Epoch 99: val_loss did not improve from 1.64449
#
# Epoch 100: val_loss did not improve from 1.64449
#
# Epoch 101: val_loss did not improve from 1.64449
#
# Epoch 102: val_loss did not improve from 1.64449
#
# Epoch 103: val_loss did not improve from 1.64449
#
# Epoch 104: val_loss did not improve from 1.64449
#
# Epoch 105: val_loss did not improve from 1.64449
#
# Epoch 106: val_loss did not improve from 1.64449
#
# Epoch 107: val_loss did not improve from 1.64449
#
# Epoch 108: val_loss did not improve from 1.64449
#
# Epoch 109: val_loss did not improve from 1.64449
#
# Epoch 110: val_loss did not improve from 1.64449
#
# Epoch 111: val_loss did not improve from 1.64449
#
# Epoch 112: val_loss did not improve from 1.64449
#
# Epoch 113: val_loss did not improve from 1.64449
#
# Epoch 114: val_loss did not improve from 1.64449
#
# Epoch 115: val_loss did not improve from 1.64449
#
# Epoch 116: val_loss did not improve from 1.64449
#
# Epoch 117: val_loss did not improve from 1.64449
#
# Epoch 118: val_loss did not improve from 1.64449
#
# Epoch 119: val_loss did not improve from 1.64449
#
# Epoch 120: val_loss did not improve from 1.64449
#
# Epoch 121: val_loss did not improve from 1.64449
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0397 - val_accuracy: 0.5660 - val_loss: 1.6798
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 0.5660 - val_loss: 1.7083
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0356 - val_accuracy: 0.5660 - val_loss: 1.7371
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0336 - val_accuracy: 0.5660 - val_loss: 1.7661
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 0.5660 - val_loss: 1.7945
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 0.5660 - val_loss: 1.8207
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 0.5660 - val_loss: 1.8482
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 0.5660 - val_loss: 1.8753
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.5660 - val_loss: 1.9011
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0244 - val_accuracy: 0.5660 - val_loss: 1.9258
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0232 - val_accuracy: 0.5660 - val_loss: 1.9508
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0221 - val_accuracy: 0.5660 - val_loss: 1.9757
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0210 - val_accuracy: 0.5660 - val_loss: 1.9999
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0200 - val_accuracy: 0.5660 - val_loss: 2.0250
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.5660 - val_loss: 2.0488
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.5660 - val_loss: 2.0726
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.5660 - val_loss: 2.0960
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.5660 - val_loss: 2.1180
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.5660 - val_loss: 2.1398
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.5660 - val_loss: 2.1619
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.5660 - val_loss: 2.1836
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.5660 - val_loss: 2.2048
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.5660 - val_loss: 2.2242
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0126 - val_accuracy: 0.5660 - val_loss: 2.2448
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.5472 - val_loss: 2.2648
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.5472 - val_loss: 2.2850
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.5472 - val_loss: 2.3041
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.5472 - val_loss: 2.3230
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.5472 - val_loss: 2.3421
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.5472 - val_loss: 2.3615
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.5472 - val_loss: 2.3807
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.5472 - val_loss: 2.3995
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.5472 - val_loss: 2.4170
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.5472 - val_loss: 2.4339
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.5472 - val_loss: 2.4524
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0076 - val_accuracy: 0.5472 - val_loss: 2.4699
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.5472 - val_loss: 2.4860
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.5472 - val_loss: 2.5032
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.5472 - val_loss: 2.5198
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.5472 - val_loss: 2.5356
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.5472 - val_loss: 2.5516
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.5472 - val_loss: 2.5675
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.5472 - val_loss: 2.5832
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.5472 - val_loss: 2.5987
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.5472 - val_loss: 2.6137
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.5472 - val_loss: 2.6290
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5472 - val_loss: 2.6439
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.5472 - val_loss: 2.6584
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.5472 - val_loss: 2.6730
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.5472 - val_loss: 2.6874
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.5472 - val_loss: 2.7018
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.5472 - val_loss: 2.7157
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.5472 - val_loss: 2.7293
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.5472 - val_loss: 2.7426
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.5472 - val_loss: 2.7562
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.5472 - val_loss: 2.7694
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5472 - val_loss: 2.7827
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5472 - val_loss: 2.7963
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5472 - val_loss: 2.8088
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5472 - val_loss: 2.8213
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5472 - val_loss: 2.8341
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5472 - val_loss: 2.8459
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5472 - val_loss: 2.8577
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5472 - val_loss: 2.8698
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.5472 - val_loss: 2.8814
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5472 - val_loss: 2.8929
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5472 - val_loss: 2.9046
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5472 - val_loss: 2.9157
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5472 - val_loss: 2.9270
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5472 - val_loss: 2.9381
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5472 - val_loss: 2.9490
# Epoch 111/200
# ...
# Epoch 141/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.5556 - val_loss: 0.8527
# Epoch 142/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.5556 - val_loss: 0.8544
# Epoch 143/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.5556 - val_loss: 0.8561
# Epoch 144/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.5556 - val_loss: 0.8577
# Epoch 145/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.5556 - val_loss: 0.8594
# Epoch 146/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.5556 - val_loss: 0.8610
# Epoch 147/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5556 - val_loss: 0.8627
# Epoch 148/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.5556 - val_loss: 0.8643
# Epoch 149/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.5556 - val_loss: 0.8659
# Epoch 150/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.5556 - val_loss: 0.8675
# Epoch 151/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5556 - val_loss: 0.8690
# Epoch 152/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.5556 - val_loss: 0.8705
# Epoch 153/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5556 - val_loss: 0.8721
# Epoch 154/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.5556 - val_loss: 0.8736
# Epoch 155/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5556 - val_loss: 0.8752
# Epoch 156/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5556 - val_loss: 0.8767
# Epoch 157/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5556 - val_loss: 0.8782
# Epoch 158/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.5556 - val_loss: 0.8797
# Epoch 159/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5556 - val_loss: 0.8812
# Epoch 160/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.5556 - val_loss: 0.8827
# Epoch 161/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5556 - val_loss: 0.8842
# Epoch 162/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5556 - val_loss: 0.8857
# Epoch 163/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.5556 - val_loss: 0.8872
# Epoch 164/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.5556 - val_loss: 0.8886
# Epoch 165/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.5556 - val_loss: 0.8900
# Epoch 166/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5556 - val_loss: 0.8914
# Epoch 167/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5556 - val_loss: 0.8928
# Epoch 168/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5556 - val_loss: 0.8943
# Epoch 169/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5556 - val_loss: 0.8957
# Epoch 170/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5556 - val_loss: 0.8971
# Epoch 171/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.5556 - val_loss: 0.8986
# Epoch 172/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5556 - val_loss: 0.8999
# Epoch 173/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5556 - val_loss: 0.9013
# Epoch 174/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.5556 - val_loss: 0.9026
# Epoch 175/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5556 - val_loss: 0.9040
# Epoch 176/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5556 - val_loss: 0.9054
# Epoch 177/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.5556 - val_loss: 0.9068
# Epoch 178/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 0.9082
# Epoch 179/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 0.9095
# Epoch 180/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 0.9108
# Epoch 181/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.5556 - val_loss: 0.9121
# Epoch 182/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5556 - val_loss: 0.9134
# Epoch 183/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5556 - val_loss: 0.9148
# Epoch 184/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5556 - val_loss: 0.9161
# Epoch 185/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5556 - val_loss: 0.9174
# Epoch 186/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5556 - val_loss: 0.9187
# Epoch 187/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5556 - val_loss: 0.9200
# Epoch 188/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.5556 - val_loss: 0.9212
# Epoch 189/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 0.9225
# Epoch 190/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 0.9238
# Epoch 191/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 0.9251
# Epoch 192/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.5556 - val_loss: 0.9264
# Epoch 193/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5556 - val_loss: 0.9276
# Epoch 194/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5556 - val_loss: 0.9288
# Epoch 195/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5556 - val_loss: 0.9300
# Epoch 196/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5556 - val_loss: 0.9313
# Epoch 197/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.5556 - val_loss: 0.9326
# Epoch 198/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5556 - val_loss: 0.9338
# Epoch 199/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5556 - val_loss: 0.9350
# Epoch 200/200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5556 - val_loss: 0.9362
#
# Epoch 1: val_loss improved from inf to 1.09409, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 2: val_loss improved from 1.09409 to 1.07590, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 3: val_loss improved from 1.07590 to 1.05432, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 4: val_loss improved from 1.05432 to 1.02917, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 5: val_loss improved from 1.02917 to 1.00059, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 6: val_loss improved from 1.00059 to 0.96882, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 7: val_loss improved from 0.96882 to 0.93536, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 8: val_loss improved from 0.93536 to 0.90241, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 9: val_loss improved from 0.90241 to 0.87218, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 10: val_loss improved from 0.87218 to 0.84529, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 11: val_loss improved from 0.84529 to 0.82264, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 12: val_loss improved from 0.82264 to 0.80411, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 13: val_loss improved from 0.80411 to 0.78870, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 14: val_loss improved from 0.78870 to 0.77563, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 15: val_loss improved from 0.77563 to 0.76414, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 16: val_loss improved from 0.76414 to 0.75436, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 17: val_loss improved from 0.75436 to 0.74597, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 18: val_loss improved from 0.74597 to 0.73901, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 19: val_loss improved from 0.73901 to 0.73319, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 20: val_loss improved from 0.73319 to 0.72830, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 21: val_loss improved from 0.72830 to 0.72420, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 22: val_loss improved from 0.72420 to 0.72079, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 23: val_loss improved from 0.72079 to 0.71800, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 24: val_loss improved from 0.71800 to 0.71574, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 25: val_loss improved from 0.71574 to 0.71395, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 26: val_loss improved from 0.71395 to 0.71259, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 27: val_loss improved from 0.71259 to 0.71158, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 28: val_loss improved from 0.71158 to 0.71090, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 29: val_loss improved from 0.71090 to 0.71055, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 30: val_loss improved from 0.71055 to 0.71047, saving model to ./project_kbo/models/전병우_model.keras
#
# Epoch 31: val_loss did not improve from 0.71047
#
# Epoch 32: val_loss did not improve from 0.71047
#
# Epoch 33: val_loss did not improve from 0.71047
#
# Epoch 34: val_loss did not improve from 0.71047
#
# Epoch 35: val_loss did not improve from 0.71047
#
# Epoch 36: val_loss did not improve from 0.71047
#
# Epoch 37: val_loss did not improve from 0.71047
#
# Epoch 38: val_loss did not improve from 0.71047
#
# Epoch 39: val_loss did not improve from 0.71047
#
# Epoch 40: val_loss did not improve from 0.71047
#
# Epoch 41: val_loss did not improve from 0.71047
#
# Epoch 42: val_loss did not improve from 0.71047
#
# Epoch 43: val_loss did not improve from 0.71047
#
# Epoch 44: val_loss did not improve from 0.71047
#
# Epoch 45: val_loss did not improve from 0.71047
#
# Epoch 46: val_loss did not improve from 0.71047
#
# Epoch 47: val_loss did not improve from 0.71047
#
# Epoch 48: val_loss did not improve from 0.71047
#
# Epoch 49: val_loss did not improve from 0.71047
#
# Epoch 50: val_loss did not improve from 0.71047
#
# Epoch 51: val_loss did not improve from 0.71047
#
# Epoch 52: val_loss did not improve from 0.71047
#
# Epoch 53: val_loss did not improve from 0.71047
#
# Epoch 54: val_loss did not improve from 0.71047
#
# Epoch 55: val_loss did not improve from 0.71047
#
# Epoch 56: val_loss did not improve from 0.71047
#
# Epoch 57: val_loss did not improve from 0.71047
#
# Epoch 58: val_loss did not improve from 0.71047
#
# Epoch 59: val_loss did not improve from 0.71047
#
# Epoch 60: val_loss did not improve from 0.71047
#
# Epoch 61: val_loss did not improve from 0.71047
#
# Epoch 62: val_loss did not improve from 0.71047
#
# Epoch 63: val_loss did not improve from 0.71047
#
# Epoch 64: val_loss did not improve from 0.71047
#
# Epoch 65: val_loss did not improve from 0.71047
#
# Epoch 66: val_loss did not improve from 0.71047
#
# Epoch 67: val_loss did not improve from 0.71047
#
# Epoch 68: val_loss did not improve from 0.71047
#
# Epoch 69: val_loss did not improve from 0.71047
#
# Epoch 70: val_loss did not improve from 0.71047
#
# Epoch 71: val_loss did not improve from 0.71047
#
# Epoch 72: val_loss did not improve from 0.71047
#
# Epoch 73: val_loss did not improve from 0.71047
#
# Epoch 74: val_loss did not improve from 0.71047
#
# Epoch 75: val_loss did not improve from 0.71047
#
# Epoch 76: val_loss did not improve from 0.71047
#
# Epoch 77: val_loss did not improve from 0.71047
#
# Epoch 78: val_loss did not improve from 0.71047
#
# Epoch 79: val_loss did not improve from 0.71047
#
# Epoch 80: val_loss did not improve from 0.71047
#
# Epoch 81: val_loss did not improve from 0.71047
#
# Epoch 82: val_loss did not improve from 0.71047
#
# Epoch 83: val_loss did not improve from 0.71047
#
# Epoch 84: val_loss did not improve from 0.71047
#
# Epoch 85: val_loss did not improve from 0.71047
#
# Epoch 86: val_loss did not improve from 0.71047
#
# Epoch 87: val_loss did not improve from 0.71047
#
# Epoch 88: val_loss did not improve from 0.71047
#
# Epoch 89: val_loss did not improve from 0.71047
#
# Epoch 90: val_loss did not improve from 0.71047
#
# Epoch 91: val_loss did not improve from 0.71047
#
# Epoch 92: val_loss did not improve from 0.71047
#
# Epoch 93: val_loss did not improve from 0.71047
#
# Epoch 94: val_loss did not improve from 0.71047
#
# Epoch 95: val_loss did not improve from 0.71047
#
# Epoch 96: val_loss did not improve from 0.71047
#
# Epoch 97: val_loss did not improve from 0.71047
#
# Epoch 98: val_loss did not improve from 0.71047
#
# Epoch 99: val_loss did not improve from 0.71047
#
# Epoch 100: val_loss did not improve from 0.71047
#
# Epoch 101: val_loss did not improve from 0.71047
#
# Epoch 102: val_loss did not improve from 0.71047
#
# Epoch 103: val_loss did not improve from 0.71047
#
# Epoch 104: val_loss did not improve from 0.71047
#
# Epoch 105: val_loss did not improve from 0.71047
#
# Epoch 106: val_loss did not improve from 0.71047
#
# Epoch 107: val_loss did not improve from 0.71047
#
# Epoch 108: val_loss did not improve from 0.71047
#
# Epoch 109: val_loss did not improve from 0.71047
#
# Epoch 110: val_loss did not improve from 0.71047
#
# Epoch 111: val_loss did not improve from 0.71047
#
# Epoch 112: val_loss did not improve from 0.71047
#
# Epoch 113: val_loss did not improve from 0.71047
#
# Epoch 114: val_loss did not improve from 0.71047
#
# Epoch 115: val_loss did not improve from 0.71047
#
# Epoch 116: val_loss did not improve from 0.71047
#
# Epoch 117: val_loss did not improve from 0.71047
#
# Epoch 118: val_loss did not improve from 0.71047
#
# Epoch 119: val_loss did not improve from 0.71047
#
# Epoch 120: val_loss did not improve from 0.71047
#
# Epoch 121: val_loss did not improve from 0.71047
#
# Epoch 122: val_loss did not improve from 0.71047
#
# Epoch 123: val_loss did not improve from 0.71047
#
# Epoch 124: val_loss did not improve from 0.71047
#
# Epoch 125: val_loss did not improve from 0.71047
#
# Epoch 126: val_loss did not improve from 0.71047
#
# Epoch 127: val_loss did not improve from 0.71047
#
# Epoch 128: val_loss did not improve from 0.71047
#
# Epoch 129: val_loss did not improve from 0.71047
#
# Epoch 130: val_loss did not improve from 0.71047
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9500 - loss: 0.2725
# 테스트 손실: 0.2725
# 테스트 정확도: 0.9500
# 모델 저장 완료: ./project_kbo/models/전병우_model.keras

# %% [markdown]
# 직접 상황을 입력해서 안타 여부를 결정하는 모델

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model

def preprocess_user_input(user_input, model, scaler, X_train_columns):
    # 사용자 입력 데이터프레임 생성
    user_data = pd.DataFrame(user_input, index=[0])

    # 범주형 변수를 수치형 변수로 변환
    user_data_processed = pd.get_dummies(user_data)

    # 학습 데이터와 동일한 특성 조정
    missing_cols = set(X_train_columns) - set(user_data_processed.columns)
    for col in missing_cols:
        user_data_processed[col] = 0

    # 열의 순서를 학습 데이터와 동일하게 맞추기
    user_data_processed = user_data_processed[X_train_columns]

    # 데이터 표준화
    user_data_scaled = scaler.transform(user_data_processed)  # 학습 데이터에서 훈련한 스케일러를 사용해야 함

    return user_data_scaled

def get_user_input():
    print("데이터를 입력하세요.")
    inning = input("이닝 (예: '9회'): ")
    pitcher = input("투수 (예: '김원중'): ")
    bc = input("볼 카운트 (예: '02-02'): ")
    out = input("아웃 카운트 (예: '1사'): ")
    bases = input("베이스 상황 (예: '1,2루'): ")

    return {
        'Inning': [inning],
        'Pitcher': [pitcher],
        'BC': [bc],
        'Out': [out],
        'Bases': [bases]
    }

# 모델 로드
model_filename = './project_kbo/models/deep_learning_model.keras'
model = load_model(model_filename)

# X_train의 열 정보 가져오기
X_train = pd.read_csv('./project_kbo/data/Playing_completed.csv').drop(columns=['Result'])
X_train = pd.get_dummies(X_train)
X_train_columns = X_train.columns

# 스케일러 로드
# 예: scaler = joblib.load('scaler.joblib')
scaler = StandardScaler()
scaler.fit(X_train)  # 실제로는 저장된 스케일러를 사용해야 합니다.

# 사용자 입력 받기
user_input = get_user_input()

# 데이터 전처리
user_data_scaled = preprocess_user_input(user_input, model, scaler, X_train_columns)

# 예측 수행
predictions = model.predict(user_data_scaled)

# 예측 결과를 0 또는 1로 변환
predicted_class = np.argmax(predictions, axis=1)

# 결과 출력
if predicted_class[0] == 1:
    print("예측 결과: 안타!")
else:
    print("예측 결과: 노 안타..")

# %% [markdown]
# 예측값과 결과값만 비교한 경우

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# 데이터 로딩
file_path = './project_kbo/data/Playing_completed.csv'
df = pd.read_csv(file_path)

# 특성(X)과 타겟(y) 분리
X = df.drop(columns=['Result'])
y = df['Result']

# 범주형 변수를 수치형 변수로 변환
X = pd.get_dummies(X)

# 스케일러 로드
scaler_filename = './project_kbo/models/scaler.joblib'
scaler = joblib.load(scaler_filename)

# 데이터 표준화
X_scaled = scaler.transform(X)

# 모델 로드
model_filename = './project_kbo/models/deep_learning_model.keras'
model = load_model(model_filename)

# 예측 수행
predictions = model.predict(X_scaled)

# 예측 결과를 0 또는 1로 변환
predicted_classes = np.argmax(predictions, axis=1)

# 원본 데이터의 실제 결과와 예측 결과를 비교
comparison_df = pd.DataFrame({
    'Actual Result': y,
    'Predicted Result': predicted_classes
})

# 정확도 계산
accuracy = np.mean(predicted_classes == y)
print(f"모델 정확도: {accuracy:.4f}")

# 결과 출력
print("실제 결과와 예측 결과 비교:")
print(comparison_df.head())

# 예측 결과를 파일로 저장
comparison_filename = './project_kbo/results/comparison_results.csv'
comparison_df.to_csv(comparison_filename, index=False)
print(f"예측 결과 저장 완료: {comparison_filename}")

# %% [markdown]
# 원래 정보와 그 옆에 예측값, 결과값이 다 나와있는 표

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# 데이터 로딩
file_path = './project_kbo/data/Playing_completed.csv'
df = pd.read_csv(file_path)

# 특성(X)과 타겟(y) 분리
X = df.drop(columns=['Result'])
y = df['Result']

# 원본 데이터의 특성을 저장
original_features = df[['Inning', 'Pitcher', 'BC', 'Out', 'Bases']].copy()

# 범주형 변수를 수치형 변수로 변환
X = pd.get_dummies(X)

# 스케일러 로드
scaler_filename = './project_kbo/models/scaler.joblib'
scaler = joblib.load(scaler_filename)

# 데이터 표준화
X_scaled = scaler.transform(X)

# 모델 로드
model_filename = './project_kbo/models/deep_learning_model.keras'
model = load_model(model_filename)

# 예측 수행
predictions = model.predict(X_scaled)

# 예측 결과를 0 또는 1로 변환
predicted_classes = np.argmax(predictions, axis=1)

# 원본 데이터의 실제 결과와 예측 결과를 비교
comparison_df = pd.DataFrame({
    'Inning': original_features['Inning'],
    'Pitcher': original_features['Pitcher'],
    'Ball Count': original_features['BC'],
    'Out Count': original_features['Out'],
    'Runner Situation': original_features['Bases'],
    'Actual Result': y,
    'Predicted Result': predicted_classes
})

# 정확도 계산
accuracy = np.mean(predicted_classes == y)
print(f"모델 정확도: {accuracy:.4f}")

# 결과 출력
print("실제 결과와 예측 결과 비교:")
print(comparison_df.head())

# 예측 결과를 파일로 저장
comparison_filename = './project_kbo/results/comparison_results_with_features.csv'
comparison_df.to_csv(comparison_filename, index=False)
print(f"예측 결과 저장 완료: {comparison_filename}")
